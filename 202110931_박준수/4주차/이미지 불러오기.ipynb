# %% [markdown]
# <a href="https://colab.research.google.com/github/junsoo321/public-repository/blob/main/3%EC%A3%BC%EC%B0%A8%20%EC%9D%B4%EB%AF%B8%EC%A7%80%20%EB%B6%88%EB%9F%AC%EC%98%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
import glob

import cv2
import numpy as np
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/drive/MyDrive/test.jpg',cv2.IMREAD_COLOR)
height, width=img.shape[:2]
M=np.array([[1,0,100],[0,1,200]],dtype=float)
dst=cv2.warpAffine(img,M,(width,height))
result=cv2.hconcat([img,dst])
cv2_imshow(result)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=592x170>

# %% [markdown]
# https://drive.google.com/uc?id=1-YJ1RdRehY1IZ86UvUg7Fg5WV9tjIPyF
