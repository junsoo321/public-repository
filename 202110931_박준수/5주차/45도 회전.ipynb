# %% [markdown]
# <a href="https://colab.research.google.com/github/junsoo321/public-repository/blob/main/45%EB%8F%84%20%ED%9A%8C%EC%A0%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
import glob

import cv2
import numpy as np
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/drive/MyDrive/test.jpg',cv2.IMREAD_COLOR)
height, width=img.shape[:2]
angle=45
center=(width/2,height/2)
rotation_matrix=cv2.getRotationMatrix2D(center,angle,1)

dst=cv2.warpAffine(img,rotation_matrix,(width,height))
result=cv2.hconcat([img,dst])
cv2_imshow(result)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=592x170>
